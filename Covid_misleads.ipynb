# %% [markdown]
# ## Exercise one
#
# Here is a ilustration of the SIR model

# %% [markdown]
# Figure 1 SIR model in spanish wikipedia taked from https://es.wikipedia.org/wiki/Modelo_SIR#/media/Archivo:ModeloSIR-Continuo.png
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 2 SIR model from english wikipedia taked from https://en.wikipedia.org/wiki/File:Graph_SIR_model_without_vital_dynamics.svg
#
# Yellow=Susceptible, Maroon=Infectious, Teal=Recovered
# ![image.png](attachment:image.png)

# %% [markdown]
# Figure 3 Beta distribution, taked from: https://en.wikipedia.org/wiki/Beta_distribution
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Distributión for the infected people
# As we can see the model for SIR it is based on three variables, one of them the maroon from figure 2 determines the people who are infected along the time, that can be in days, weeks, or other measure of time.
# We can see that the infected people can obtain a gaussian distribution, only by specific values, that means that the curve at the right only can be simetric to the left on very especific situations.
#
# ### Behavior of an epidemic
# The parameter in whom the distribution can be similar to gaussian are determined by a function called $R_0$, who is estatistically determined, and tell us the velocity of the infection, I mean the differential betwen the intected peopple with the time.
#
# The $R_0$ in Mexico is at leat 2.5 for the two first month, so this tell us that the distribution(figure 3) behaves like an beta distribution with an $1<\alpha<\beta$

# %% [markdown]
# Figure 4 forecast in epidemilogic model for mexico in june taked from https://prensaobjetiva.com/2020/06/10/proyecciones-de-casos-y-hospitalizaciones-por-covid-19-se-vieron-rebasadas-en-el-valle-de-mexico/
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Failure in the models for determine contagius in covid pandemic in some countries.
#
# So, as we see on figure 4 we fall in behaviors like the 5.2 Using Graphic Forms in Inappropriate Ways and 5.3 The Ignorance of Evidence-Driven Communicators.
#
# The 5.3 is explained because it looks in some form it would no become simetrical, o reach the gausian model, there is no evidence that makes us to think that the behavior for the future will reachh that mathematical model. The forecast lacks of evidence.
#
# The behavior for the curve on forecast depends on a lot of variables, we must consider movilization, interactions betwen peoples, and other social factors.
#
# The 5.2 is explained as consecuence from the 5.3, because we consider the left side has a behavior it would not implies that the right side will have a similar. So the graphics show that the curves are descending in the velocity of propagation. This use of the geometric form to hide the future and try to obscure that contagius would not stop to increase is a clear use the graphic information in unapropiate ways. Alongside, some countries, communicators and mediums are saying of second waves, when most of the countries never stoped the first.
#
# ### Intended audience
#
# Those model are intended for general public, because they are on tv, radius and public mediums.
